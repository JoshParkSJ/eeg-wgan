# %% [markdown]
# # Simplified Workflow (Real Data)

# %%
import mne
import numpy as np 
import matplotlib.pyplot as plt
import torch
import os
import sklearn
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import ShuffleSplit, cross_val_score, train_test_split
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms

# %% [markdown]
# ## Extracting the data

# %%
main_folder = '../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0'

subdirectories = [f.path for f in os.scandir(main_folder) if f.is_dir()]

opened_files = []
closed_files = []

for subdirectory in subdirectories:
    files = os.listdir(subdirectory)
    
    if len(files) > 0:
        for file in files:
            
            if file[-6:] == '01.edf':
                # This is data for eyes opened
                eyes_opened = os.path.join(subdirectory, file)
                print(eyes_opened)
                opened_files.append(eyes_opened)

            if file[-6:] == '02.edf':
                # This is data for eyes closed
                eyes_closed = os.path.join(subdirectory, file)
                print(eyes_closed)
                closed_files.append(eyes_closed)
    else:
        print(f"No files found in {subdirectory}")
        
data_loc = "../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/"
raw = mne.io.read_raw_edf('../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R01.edf', preload=True)
annotations = raw.annotations
annotations[0]


REAL_EYES_OPEN = '../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R01.edf'
REAL_EYES_CLOSED = '../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R02.edf'
# Out:
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S001\S001R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S001\S001R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S002\S002R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S002\S002R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S003\S003R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S003\S003R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S004\S004R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S004\S004R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S005\S005R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S005\S005R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S006\S006R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S006\S006R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S007\S007R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S007\S007R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S008\S008R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S008\S008R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S009\S009R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S009\S009R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S010\S010R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S010\S010R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S011\S011R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S011\S011R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S012\S012R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S012\S012R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S013\S013R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S013\S013R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S014\S014R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S014\S014R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S015\S015R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S015\S015R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S016\S016R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S016\S016R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S017\S017R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S017\S017R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S018\S018R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S018\S018R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S019\S019R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S019\S019R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S020\S020R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S020\S020R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S021\S021R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S021\S021R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S022\S022R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S022\S022R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S023\S023R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S023\S023R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S024\S024R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S024\S024R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S025\S025R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S025\S025R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S026\S026R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S026\S026R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S027\S027R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S027\S027R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S028\S028R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S028\S028R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S029\S029R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S029\S029R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S030\S030R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S030\S030R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S031\S031R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S031\S031R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S032\S032R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S032\S032R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S033\S033R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S033\S033R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S034\S034R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S034\S034R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S035\S035R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S035\S035R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S036\S036R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S036\S036R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S037\S037R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S037\S037R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S038\S038R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S038\S038R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S039\S039R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S039\S039R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S040\S040R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S040\S040R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S041\S041R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S041\S041R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S042\S042R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S042\S042R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S043\S043R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S043\S043R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S044\S044R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S044\S044R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S045\S045R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S045\S045R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S046\S046R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S046\S046R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S047\S047R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S047\S047R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S048\S048R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S048\S048R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S049\S049R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S049\S049R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S050\S050R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S050\S050R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S051\S051R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S051\S051R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S052\S052R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S052\S052R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S053\S053R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S053\S053R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S054\S054R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S054\S054R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S055\S055R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S055\S055R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S056\S056R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S056\S056R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S057\S057R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S057\S057R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S058\S058R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S058\S058R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S059\S059R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S059\S059R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S060\S060R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S060\S060R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S061\S061R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S061\S061R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S062\S062R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S062\S062R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S063\S063R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S063\S063R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S064\S064R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S064\S064R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S065\S065R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S065\S065R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S066\S066R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S066\S066R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S067\S067R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S067\S067R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S068\S068R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S068\S068R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S069\S069R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S069\S069R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S070\S070R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S070\S070R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S071\S071R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S071\S071R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S072\S072R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S072\S072R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S073\S073R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S073\S073R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S074\S074R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S074\S074R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S075\S075R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S075\S075R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S076\S076R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S076\S076R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S077\S077R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S077\S077R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S078\S078R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S078\S078R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S079\S079R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S079\S079R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S080\S080R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S080\S080R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S081\S081R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S081\S081R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S082\S082R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S082\S082R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S083\S083R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S083\S083R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S084\S084R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S084\S084R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S085\S085R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S085\S085R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S086\S086R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S086\S086R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S087\S087R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S087\S087R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S088\S088R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S088\S088R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S089\S089R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S089\S089R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S090\S090R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S090\S090R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S091\S091R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S091\S091R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S092\S092R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S092\S092R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S093\S093R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S093\S093R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S094\S094R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S094\S094R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S095\S095R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S095\S095R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S096\S096R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S096\S096R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S097\S097R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S097\S097R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S098\S098R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S098\S098R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S099\S099R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S099\S099R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S100\S100R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S100\S100R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S101\S101R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S101\S101R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S102\S102R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S102\S102R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S103\S103R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S103\S103R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S104\S104R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S104\S104R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S105\S105R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S105\S105R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S106\S106R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S106\S106R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S107\S107R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S107\S107R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S108\S108R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S108\S108R02.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S109\S109R01.edf
# ../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S109\S109R02.edf
# Extracting EDF parameters from c:\Users\joshua.park\Desktop\eeg-wgan\data\training\EEGData\MNE-eegbci-data\files\eegmmidb\1.0.0\S001\S001R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...

# %% [markdown]
# ## Plot EEG signals for multiple channels

# %%
event_descriptions, event_counts = np.unique(annotations.description, return_counts=True)

# Print event descriptions and their counts
for desc, count in zip(event_descriptions, event_counts):
    print(f"Event: {desc}, Count: {count}")

# Select specific event type (replace 'event_type' with your desired event description)
event_type = 'event_type'
events = annotations[annotations.description == event_type]

# Print out event onset times and durations
for idx, event in enumerate(events):
    print(f"Event {idx + 1}: Onset: {event['onset']:.2f}, Duration: {event['duration']:.2f}")

# Replace 'your_file.edf' with the actual path to your EDF file
raw =  mne.io.read_raw_edf(REAL_EYES_OPEN, preload=True) # eyes open
print("eyes open")
raw.plot(scalings='auto', title='EEG Channels')

raw =  mne.io.read_raw_edf(REAL_EYES_CLOSED, preload=True) # eyes closed
print("eyes closed")
raw.plot(scalings='auto', title='EEG Channels')

# Get EEG data for all channels
eeg_data = raw.get_data()

# Print the shape of the EEG data array
print("EEG data shape:", eeg_data.shape)


# # List of EDF file paths
# edf_files = ['../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R06.edf', 
# '../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R10.edf',
# '../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R14.edf']

# # List comprehension to read all EDF files
# raw_list = [mne.io.read_raw_edf(edf_file, preload=True) for edf_file in edf_files]


# # Extract EEG data for all channels from each raw object
# eeg_data_list = [raw.get_data() for raw in raw_list]

# # Print the shape of the EEG data arrays for each file
# for idx, eeg_data in enumerate(eeg_data_list):
#     print(f"EEG data shape for file {edf_files[idx]}:", eeg_data.shape)

# raw_list[0].plot(scalings='auto', title='EEG Channels')
# Out:
# Event: T0, Count: 1
# Extracting EDF parameters from c:\Users\joshua.park\Desktop\eeg-wgan\data\training\EEGData\MNE-eegbci-data\files\eegmmidb\1.0.0\S001\S001R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# eyes open
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Extracting EDF parameters from c:\Users\joshua.park\Desktop\eeg-wgan\data\training\EEGData\MNE-eegbci-data\files\eegmmidb\1.0.0\S001\S001R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# eyes closed
# <MNEBrowseFigure size 800x800 with 4 Axes>
# EEG data shape: (64, 9760)

# %% [markdown]
# ## Visualizing the Data

# %%
# raw.compute_psd(fmax=50).plot(picks="data", exclude="bads")
# raw.plot(duration=5, n_channels=30)

# %%
# def basic_plot(file_path):
#     data = mne.io.read_raw_edf(file_path, preload=True, verbose=False)
#     eeg_data = data.get_data()
#     time = data.times
#     plt.figure(figsize=(10, 6))
#     for ch_idx in range(eeg_data.shape[0]):
#         plt.plot(time, eeg_data[ch_idx], label=f'Channel {ch_idx + 1}')
#     plt.xlabel('Time (s)')
#     plt.ylabel('Amplitude')
#     plt.title('EEG Data for All Channels')
#     return plt.show()

# print("eyes open")
# basic_plot('../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/S002/S002R01.edf')
# print("eyes closed")
# basic_plot('../data/training/EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0/S002/S002R02.edf')

# %%
def double_plot(file1, file2):
    fig, (ax1, ax2) = plt.subplots(2, 1)
    fig.suptitle('Eyes Opened vs Eyes Closed')

    data1 = mne.io.read_raw_edf(file1, preload=True, verbose=False)
    data1.filter(1.0, 30.0, fir_design="firwin", skip_by_annotation="edge", verbose=False)
    ica = mne.preprocessing.ICA(n_components=20, random_state=97, max_iter=800, verbose=False)
    ica.fit(data1, verbose=False)
    ica.exclude = [1, 2]
    data1 = ica.apply(data1, verbose=False)

    
    data2 = mne.io.read_raw_edf(file2, preload=True, verbose=False)
    data2.filter(1.0, 30.0, fir_design="firwin", skip_by_annotation="edge", verbose=False)
    ica = mne.preprocessing.ICA(n_components=20, random_state=97, max_iter=800, verbose=False)
    ica.fit(data2, verbose=False)
    ica.exclude = [1, 2]
    data2 = ica.apply(data2, verbose=False)
    

    good_channels1 = data1.info['ch_names']
    good_channels2 = data2.info['ch_names']

    eeg_data1 = data1.get_data(picks=good_channels1)
    eeg_data2 = data2.get_data(picks=good_channels2)

    time = data1.times

    ax1.plot(time, eeg_data1[0])
    ax1.set_title('Eyes Opened')
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Amplitude')
    for ch_idx in range(eeg_data1.shape[0]):
        ax1.plot(time, eeg_data1[ch_idx], label=f'Channel {ch_idx + 1}')
    ax1.set_xlim(0, 5)
    ax1.set_ylim(-0.0002, 0.0002)

    ax2.plot(time, eeg_data2[0])
    ax2.set_title('Eyes Closed')
    ax2.set_xlabel('Time (s)')
    ax2.set_ylabel('Amplitude')
    for ch_idx in range(eeg_data2.shape[0]):
        ax2.plot(time, eeg_data2[ch_idx], label=f'Channel {ch_idx + 1}')
    ax2.set_xlim(0, 5)
    ax2.set_ylim(-0.0002, 0.0002)
    return plt.show()

double_plot(REAL_EYES_OPEN, REAL_EYES_CLOSED)

# %%
def compute_psd(data, fs, nperseg=256, noverlap=None):
    """
    Compute Power Spectral Density (PSD) using the Welch method.

    Parameters:
        data (array): EEG data array with shape (n_channels, n_samples).
        fs (float): Sampling frequency.
        nperseg (int): Length of each segment for PSD estimation.
        noverlap (int): Number of overlapping samples between segments.
    
    Returns:
        freqs (array): Frequency values.
        psd (array): Power Spectral Density values.
    """
    n_channels, n_samples = data.shape
    psd = np.zeros((n_channels, nperseg // 2 + 1))

    for ch_idx in range(n_channels):
        f, Pxx = plt.psd(data[ch_idx], Fs=fs, NFFT=nperseg, noverlap=noverlap)
        # Add a small epsilon to avoid zero values
        psd[ch_idx] = Pxx + 1e-10

    return f, psd

def average_across_arrays(generated_data):
    return generated_data.mean(axis=0)

def plot_psd(eeg_data):
    # Set the sampling frequency
    fs = raw.info['sfreq']
    print("sampling frequency: ", fs)

    # Compute PSD using the custom function
    freqs, psd = compute_psd(eeg_data, fs)

    # Plot the PSD
    plt.figure(figsize=(10, 6))  # Add this line to create a single figure
    for ch_idx in range(eeg_data.shape[0]):
        plt.semilogy(freqs, psd[ch_idx], label=f'Channel {ch_idx + 1}')

    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power/Frequency (dB/Hz)')
    plt.show()


plot_psd(raw.get_data()) # Get the EEG data using .get_data()
# Out:
# sampling frequency:  160.0

# %%
eeg_data = raw.get_data()
time = raw.times

# Plot EEG data for all channels using Matplotlib
plt.figure(figsize=(10, 6))
for ch_idx in range(eeg_data.shape[0]):
    plt.plot(time, eeg_data[ch_idx], label=f'Channel {ch_idx + 1}')

plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('EEG Data for All Channels')
plt.show()

# %% [markdown]
# ### Machine Learning with MNE

# %%
# DEfine the time window for epochs around the events
t_min, t_max = -1., 4.

# Dictionary that maps event names to their corresponding event codes.
# Event codes are numeric identifiers that are used to label different type of events or triggers in EEG/MEG data.
event_id = {'hands': 2, 'feet': 3}

# This is the subject we choose to study. Can be in the range of 1-109 (inclusive)
subject = 1

# This is the run we choose to study. Can be in the range of 1-14 (inclusive)
runs = [6, 10, 14]  # motor imagery: hands vs feet

# Loads in the subject and runs you're interested in
raw_fnames = mne.datasets.eegbci.load_data(subject, runs, '../data/training/EEGData', verbose=False)

# Loads in the data file then reads and concatenates the data into the `raw` object
raw = mne.io.concatenate_raws([mne.io.read_raw_edf(f, preload=True, verbose=False) for f in raw_fnames])

# Set channel names in the EEG data
mne.datasets.eegbci.standardize(raw)

# This creates an info object that represents the 10/05 electrode positions 
montage = mne.channels.make_standard_montage("standard_1005")

# Attaches the montage to the raw data
raw.set_montage(montage)

# This applies a bandpass filter (finite impulse response) to the data and avoids filtering data near the edge
raw.filter(7.0, 30.0, fir_design="firwin", skip_by_annotation="edge")

# This line extracts information from annotations present in the raw data.
# Annotations are labels attached to specific points in the data and usually represent events or important time segments.
events, _ = mne.events_from_annotations(raw, event_id=dict(T1=2, T2=3))

# This line selects specific channel types from the raw data
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False, exclude="bads")

epochs = mne.Epochs(
    raw, # Datase
    events, # Events
    event_id, # Event ID
    t_min, # Start time
    t_max, # End time
    proj=True, # Apply SSP projection vectors
    picks=picks, # Channels to include
    baseline=None, # Baseline interval
    preload=True, # Load data into memory
)

# This creates a new epochs object by copying the original epochs object and cropping the time interval from 1 to 2 seconds.
epochs_train = epochs.copy().crop(tmin=1.0, tmax=2.0)

# This creates a numpy array that contains the labels for each epoch. 
# The labels are stored in the last column of the events array. 
# The labels are stored as integers, but we want them to be 0 and 1. 
# We can subtract 2 from the labels to get the desired values.
labels = epochs.events[:, -1] - 2

epochs.plot(n_channels=1, n_epochs=1, scalings='auto')
# Out:
# Filtering raw data in 3 contiguous segments
# Setting up band-pass filter from 7 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 265 samples (1.656 s)
#
# Used Annotations descriptions: ['T1', 'T2']
# Not setting metadata
# 45 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 45 events and 801 original time points ...
# 0 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# C:\Users\joshua.park\AppData\Local\Temp\ipykernel_4336\178294186.py:60: FutureWarning: The current default events=None is deprecated and will change to events=True in MNE 1.6. Set events=False to suppress this warning.
#   epochs.plot(n_channels=1, n_epochs=1, scalings='auto')
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# Define a monte-carlo cross-validation generator (reduce variance):
# Keeps track of an empty list called scores for the cross-validation procedure
scores = []
# This extracts the data as a numpy array from the MNE object
epochs_data = epochs.get_data()
# This extracts the data from the epochs_train object
epochs_data_train = epochs_train.get_data()
# This line creates a cross-validation (CV) generator using the ShuffleSplit method
cv = ShuffleSplit(10, test_size=0.2, random_state=42)
# This line creates the actual cross-validation splits using the splits method of the CV generator
cv_split = cv.split(epochs_data_train)

# Assemble a classifier
lda = LinearDiscriminantAnalysis()
csp = mne.decoding.CSP(n_components=4, reg=None, log=True, norm_trace=False)

# Use scikit-learn Pipeline with cross_val_score function
clf = Pipeline([("CSP", csp), ("LDA", lda)])
scores = cross_val_score(clf, epochs_data_train, labels, cv=cv, n_jobs=None)

# Printing the results
class_balance = np.mean(labels == labels[0])
class_balance = max(class_balance, 1.0 - class_balance)
print(
    "Classification accuracy: %f / Chance level: %f" % (np.mean(scores), class_balance)
)

# This code above sets up a classification pipeline that includes CSP for feature extraction and LDA as the classifier
# It then performs cross-validation using the pipeline and prints the average classification accuracy and chance level of classification accuracy.
# This code aims to evaluate the performance of the classifier on the given EEG data and the corresponding labels using cross-validation

# plot CSP patterns estimated on full data for visualization
csp.fit_transform(epochs_data, labels)

csp.plot_patterns(epochs.info, ch_type="eeg", units="Patterns (AU)", size=1.5)
# Out:
# Computing rank from data with rank=None
#     Using tolerance 9.7e-05 (2.2e-16 eps * 64 dim * 6.8e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-05 (2.2e-16 eps * 64 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-05 (2.2e-16 eps * 64 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 64 dim * 7.5e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 64 dim * 7.6e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.1e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.5e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-05 (2.2e-16 eps * 64 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-05 (2.2e-16 eps * 64 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.3e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.1e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 64 dim * 7.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Classification accuracy: 0.933333 / Chance level: 0.533333
# Computing rank from data with rank=None
#     Using tolerance 0.00025 (2.2e-16 eps * 64 dim * 1.7e+10  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00026 (2.2e-16 eps * 64 dim * 1.9e+10  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# <MNEFigure size 1125x287.5 with 5 Axes>
# <MNEFigure size 1125x287.5 with 5 Axes>

# %%
sfreq = raw.info["sfreq"]
w_length = int(sfreq * 0.5)  # running classifier: window length
w_step = int(sfreq * 0.1)  # running classifier: window step size
w_start = np.arange(0, epochs_data.shape[2] - w_length, w_step)

scores_windows = []

for train_idx, test_idx in cv_split:
    y_train, y_test = labels[train_idx], labels[test_idx]

    X_train = csp.fit_transform(epochs_data_train[train_idx], y_train)
    X_test = csp.transform(epochs_data_train[test_idx])

    # fit classifier
    lda.fit(X_train, y_train)

    # running classifier: test classifier on sliding window
    score_this_window = []
    for n in w_start:
        X_test = csp.transform(epochs_data[test_idx][:, :, n : (n + w_length)])
        score_this_window.append(lda.score(X_test, y_test))
    scores_windows.append(score_this_window)

# Plot scores over time
w_times = (w_start + w_length / 2.0) / sfreq + epochs.tmin

plt.figure()
plt.plot(w_times, np.mean(scores_windows, 0), label="Score")
plt.axvline(0, linestyle="--", color="k", label="Onset")
plt.axhline(0.5, linestyle="-", color="k", label="Chance")
plt.xlabel("time (s)")
plt.ylabel("classification accuracy")
plt.title("Classification score over time")
plt.legend(loc="lower right")
plt.show()
# Out:
# Computing rank from data with rank=None
#     Using tolerance 9.7e-05 (2.2e-16 eps * 64 dim * 6.8e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-05 (2.2e-16 eps * 64 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-05 (2.2e-16 eps * 64 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 64 dim * 7.5e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 64 dim * 7.6e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.1e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.5e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.5e-05 (2.2e-16 eps * 64 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.6e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-05 (2.2e-16 eps * 64 dim * 6.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00012 (2.2e-16 eps * 64 dim * 8.3e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.1e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.00011 (2.2e-16 eps * 64 dim * 7.7e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.0001 (2.2e-16 eps * 64 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
