# %% [markdown]
# # Data gathering

# %%
import mne
import numpy as np 
import matplotlib.pyplot as plt
import torch
import os
import sklearn
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import ShuffleSplit, cross_val_score, train_test_split
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms

from Data import download_EEGBCI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 15
#      12 import torch.optim as optim
#      13 from torchvision import transforms
# ---> 15 from Data import download_EEGBCI
#
# ModuleNotFoundError: No module named 'Data'

# %%
if input("Are you sure you want to download the entire dataset? (Y/N)") in "Yy":
    total_subjects = list(range(1, 110))
    runs = list(range(1, 15))
    download_EEGBCI(total_subjects, runs, './EEGData', False)
    print("Downloaded everything!")

else:
    print("Download cancelled.")

# %%
main_folder = './EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0'
subdirectories = [f.path for f in os.scandir(main_folder) if f.is_dir()]

opened_files = []
closed_files = []

i = 0
for subdirectory in subdirectories:
    files = os.listdir(subdirectory)
    
    if len(files) > 0 and i not in [13, 50, 68, 96, 108]: # 13, 50, 68, 96, 108 idx does not have 9760 seq len
        for file in files:
            
            if file[-6:] == '01.edf':
                # This is data for eyes opened
                eyes_opened = os.path.join(subdirectory, file)
                print(eyes_opened)
                opened_files.append(eyes_opened)

            if file[-6:] == '02.edf':
                # This is data for eyes closed
                eyes_closed = os.path.join(subdirectory, file)
                print(eyes_closed)
                closed_files.append(eyes_closed)
    else:
        print(f"No files found in {subdirectory}")
    
    i += 1
# Out:
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S001\S001R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S001\S001R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S002\S002R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S002\S002R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S003\S003R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S003\S003R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S004\S004R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S004\S004R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S005\S005R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S005\S005R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S006\S006R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S006\S006R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S007\S007R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S007\S007R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S008\S008R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S008\S008R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S009\S009R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S009\S009R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S010\S010R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S010\S010R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S011\S011R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S011\S011R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S012\S012R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S012\S012R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S013\S013R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S013\S013R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S014
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S015\S015R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S015\S015R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S016\S016R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S016\S016R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S017\S017R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S017\S017R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S018\S018R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S018\S018R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S019\S019R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S019\S019R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S020\S020R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S020\S020R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S021\S021R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S021\S021R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S022\S022R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S022\S022R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S023\S023R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S023\S023R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S024\S024R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S024\S024R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S025\S025R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S025\S025R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S026\S026R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S026\S026R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S027\S027R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S027\S027R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S028\S028R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S028\S028R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S029\S029R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S029\S029R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S030\S030R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S030\S030R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S031\S031R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S031\S031R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S032\S032R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S032\S032R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S033\S033R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S033\S033R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S034\S034R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S034\S034R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S035\S035R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S035\S035R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S036\S036R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S036\S036R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S037\S037R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S037\S037R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S038\S038R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S038\S038R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S039\S039R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S039\S039R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S040\S040R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S040\S040R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S041\S041R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S041\S041R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S042\S042R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S042\S042R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S043\S043R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S043\S043R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S044\S044R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S044\S044R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S045\S045R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S045\S045R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S046\S046R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S046\S046R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S047\S047R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S047\S047R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S048\S048R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S048\S048R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S049\S049R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S049\S049R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S050\S050R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S050\S050R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S051
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S052\S052R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S052\S052R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S053\S053R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S053\S053R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S054\S054R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S054\S054R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S055\S055R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S055\S055R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S056\S056R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S056\S056R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S057\S057R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S057\S057R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S058\S058R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S058\S058R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S059\S059R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S059\S059R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S060\S060R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S060\S060R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S061\S061R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S061\S061R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S062\S062R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S062\S062R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S063\S063R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S063\S063R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S064\S064R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S064\S064R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S065\S065R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S065\S065R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S066\S066R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S066\S066R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S067\S067R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S067\S067R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S068\S068R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S068\S068R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S069
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S070\S070R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S070\S070R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S071\S071R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S071\S071R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S072\S072R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S072\S072R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S073\S073R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S073\S073R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S074\S074R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S074\S074R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S075\S075R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S075\S075R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S076\S076R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S076\S076R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S077\S077R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S077\S077R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S078\S078R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S078\S078R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S079\S079R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S079\S079R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S080\S080R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S080\S080R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S081\S081R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S081\S081R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S082\S082R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S082\S082R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S083\S083R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S083\S083R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S084\S084R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S084\S084R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S085\S085R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S085\S085R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S086\S086R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S086\S086R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S087\S087R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S087\S087R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S088\S088R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S088\S088R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S089\S089R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S089\S089R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S090\S090R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S090\S090R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S091\S091R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S091\S091R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S092\S092R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S092\S092R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S093\S093R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S093\S093R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S094\S094R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S094\S094R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S095\S095R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S095\S095R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S096\S096R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S096\S096R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S097
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S098\S098R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S098\S098R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S099\S099R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S099\S099R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S100\S100R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S100\S100R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S101\S101R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S101\S101R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S102\S102R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S102\S102R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S103\S103R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S103\S103R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S104\S104R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S104\S104R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S105\S105R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S105\S105R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S106\S106R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S106\S106R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S107\S107R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S107\S107R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S108\S108R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S108\S108R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S109

# %%
large_open_data = []    # This is a list of all the data for eyes opened
large_closed_data = []  # This is a list of all the data for eyes closed

for data in opened_files:
    value_open = mne.io.read_raw_edf(data, preload=True, verbose=False).get_data(verbose=False)
    if(len(value_open) == 64):
        large_open_data.append(value_open)

for data in closed_files:
    value_closed = mne.io.read_raw_edf(data, preload=True, verbose=False).get_data(verbose=False)
    if(len(value_closed) == 64):
        large_closed_data.append(value_closed)

print(large_open_data.__len__())   # This is the number of files for eyes opened
print(large_closed_data.__len__()) # This is the number of files for eyes closed

        
training_data_open = np.array(large_open_data)
training_data_closed = np.array(large_closed_data)
print(np.shape(training_data_open))
print(np.shape(training_data_closed))
# Out:
# 104
# 104
# (104, 64, 9760)
# (104, 64, 9760)

# %%
def get_fft(data, nperseg=256, noverlap=128, channels=64):
    all_fft = []

    # Create window function
    window = torch.hann_window(nperseg, dtype=torch.float)

    for x in data:
        avg_psds_db = []
        
        for ch in range(channels):
            chx = x[ch]

            # Separate x into overlapping segments
            x_segs = chx.unfold(0, nperseg, nperseg - noverlap)

            # Apply window function to each segment
            windowed_segs = x_segs * window

            # Compute power spectral density for each windowed segment
            seg_psds = torch.fft.rfft(windowed_segs, dim=1)
            seg_psds = torch.abs(seg_psds)**2

            # Average PSDs over all segments
            avg_psds = torch.mean(seg_psds, axis=0)

            # Convert to decibels
            avg_psds_db.append(torch.log10(avg_psds + 1e-10))

        avg_psds_db = torch.stack(avg_psds_db)
        all_fft.append(avg_psds_db)

    all_fft = torch.stack(all_fft, dim=0)
    return all_fft



def normalize_data(input_data):
    
    # Scale the data to range 0-1
    input_data = (input_data - np.min(input_data)) / (np.max(input_data) - np.min(input_data))
    
    # Then scale from range 0-1 to range -1 to 1
    input_data = 2*input_data - 1
    
    return input_data

# %%
data_np = []
for idx,data in enumerate(training_data_closed):
    if idx in [3,6,7,9,14,15,16,18,19,22,23,25,26,27,28,29,32,33,40,41,42,45,46,48,49,51,52,56,57,59,63,66,70,71,73,75,76,77,78,80,89,95,99,100,101]: # filter out bad data
        data_np.append(data[:,3152:6304])

short_data_normalized = []
for d in data_np:
    channels = []
    for ch in range(64):
        channels.append(normalize_data(d[ch]))
    short_data_normalized.append(channels)

np.save('normalized-training-closed-64ch', short_data_normalized)

# %%
data_np = []
for idx,data in enumerate(training_data_open):
    if idx in [3,4,5,7,9,10,11,12,14,15,16,17,18,19,21,22,24,25,26,34,37,41,45,48,49,52,56,57,60,63,64,65,66,73,80,87,89,90,96,99,100,101]: # filter out bad data
        data_np.append(data[:,3152:6304])

short_data_normalized = []
for d in data_np:
    channels = []
    for ch in range(64):
        channels.append(normalize_data(d[ch]))
    short_data_normalized.append(channels)

np.save('normalized-training-open-64ch', short_data_normalized)
