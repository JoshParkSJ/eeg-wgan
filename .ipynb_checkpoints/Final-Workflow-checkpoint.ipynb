01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S059\S059R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S060\S060R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S060\S060R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S061\S061R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S061\S061R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S062\S062R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S062\S062R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S063\S063R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S063\S063R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S064\S064R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S064\S064R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S065\S065R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S065\S065R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S066\S066R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S066\S066R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S067\S067R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S067\S067R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S068\S068R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S068\S068R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S069\S069R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S069\S069R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S070\S070R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S070\S070R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S071\S071R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S071\S071R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S072\S072R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S072\S072R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S073\S073R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S073\S073R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S074\S074R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S074\S074R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S075\S075R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S075\S075R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S076\S076R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S076\S076R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S077\S077R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S077\S077R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S078\S078R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S078\S078R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S079\S079R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S079\S079R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S080\S080R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S080\S080R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S081\S081R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S081\S081R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S082\S082R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S082\S082R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S083\S083R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S083\S083R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S084\S084R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S084\S084R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S085\S085R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S085\S085R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S086\S086R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S086\S086R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S087\S087R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S087\S087R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S088\S088R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S088\S088R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S089\S089R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S089\S089R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S090\S090R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S090\S090R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S091\S091R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S091\S091R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S092\S092R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S092\S092R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S093\S093R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S093\S093R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S094\S094R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S094\S094R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S095\S095R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S095\S095R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S096\S096R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S096\S096R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S097\S097R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S097\S097R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S098\S098R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S098\S098R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S099\S099R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S099\S099R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S100\S100R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S100\S100R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S101\S101R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S101\S101R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S102\S102R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S102\S102R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S103\S103R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S103\S103R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S104\S104R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S104\S104R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S105\S105R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S105\S105R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S106\S106R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S106\S106R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S107\S107R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S107\S107R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S108\S108R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S108\S108R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S109\S109R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S109\S109R02.edf
# 109
# 109

# %%
if input("Are you sure you want to download the entire dataset? (Y/N)") in "Yy":
    total_subjects = list(range(1, 110))
    runs = list(range(1, 15))
    download_EEGBCI(total_subjects, runs, './EEGData', False)
    print("Downloaded everything!")

else:
    print("Download cancelled.")

# %%
main_folder = './EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0'
subdirectories = [f.path for f in os.scandir(main_folder) if f.is_dir()]

opened_files = []
closed_files = []

i = 0
for subdirectory in subdirectories:
    files = os.listdir(subdirectory)
    
    if len(files) > 0 and i not in [13, 50, 68, 96, 108]: # 13, 50, 68, 96, 108 idx does not have 9760 seq len
        for file in files:
            
            if file[-6:] == '01.edf':
                # This is data for eyes opened
                eyes_opened = os.path.join(subdirectory, file)
                print(eyes_opened)
                opened_files.append(eyes_opened)

            if file[-6:] == '02.edf':
                # This is data for eyes closed
                eyes_closed = os.path.join(subdirectory, file)
                print(eyes_closed)
                closed_files.append(eyes_closed)
    else:
        print(f"No files found in {subdirectory}")
    
    i += 1
# Out:
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S001\S001R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S001\S001R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S002\S002R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S002\S002R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S003\S003R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S003\S003R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S004\S004R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S004\S004R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S005\S005R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S005\S005R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S006\S006R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S006\S006R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S007\S007R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S007\S007R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S008\S008R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S008\S008R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S009\S009R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S009\S009R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S010\S010R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S010\S010R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S011\S011R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S011\S011R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S012\S012R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S012\S012R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S013\S013R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S013\S013R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S014
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S015\S015R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S015\S015R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S016\S016R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S016\S016R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S017\S017R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S017\S017R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S018\S018R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S018\S018R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S019\S019R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S019\S019R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S020\S020R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S020\S020R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S021\S021R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S021\S021R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S022\S022R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S022\S022R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S023\S023R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S023\S023R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S024\S024R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S024\S024R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S025\S025R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S025\S025R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S026\S026R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S026\S026R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S027\S027R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S027\S027R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S028\S028R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S028\S028R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S029\S029R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S029\S029R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S030\S030R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S030\S030R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S031\S031R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S031\S031R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S032\S032R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S032\S032R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S033\S033R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S033\S033R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S034\S034R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S034\S034R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S035\S035R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S035\S035R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S036\S036R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S036\S036R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S037\S037R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S037\S037R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S038\S038R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S038\S038R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S039\S039R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S039\S039R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S040\S040R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S040\S040R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S041\S041R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S041\S041R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S042\S042R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S042\S042R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S043\S043R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S043\S043R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S044\S044R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S044\S044R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S045\S045R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S045\S045R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S046\S046R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S046\S046R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S047\S047R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S047\S047R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S048\S048R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S048\S048R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S049\S049R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S049\S049R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S050\S050R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S050\S050R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S051
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S052\S052R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S052\S052R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S053\S053R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S053\S053R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S054\S054R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S054\S054R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S055\S055R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S055\S055R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S056\S056R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S056\S056R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S057\S057R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S057\S057R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S058\S058R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S058\S058R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S059\S059R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S059\S059R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S060\S060R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S060\S060R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S061\S061R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S061\S061R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S062\S062R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S062\S062R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S063\S063R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S063\S063R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S064\S064R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S064\S064R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S065\S065R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S065\S065R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S066\S066R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S066\S066R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S067\S067R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S067\S067R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S068\S068R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S068\S068R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S069
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S070\S070R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S070\S070R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S071\S071R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S071\S071R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S072\S072R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S072\S072R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S073\S073R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S073\S073R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S074\S074R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S074\S074R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S075\S075R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S075\S075R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S076\S076R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S076\S076R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S077\S077R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S077\S077R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S078\S078R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S078\S078R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S079\S079R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S079\S079R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S080\S080R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S080\S080R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S081\S081R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S081\S081R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S082\S082R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S082\S082R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S083\S083R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S083\S083R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S084\S084R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S084\S084R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S085\S085R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S085\S085R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S086\S086R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S086\S086R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S087\S087R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S087\S087R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S088\S088R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S088\S088R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S089\S089R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S089\S089R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S090\S090R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S090\S090R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S091\S091R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S091\S091R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S092\S092R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S092\S092R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S093\S093R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S093\S093R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S094\S094R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S094\S094R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S095\S095R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S095\S095R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S096\S096R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S096\S096R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S097
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S098\S098R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S098\S098R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S099\S099R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S099\S099R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S100\S100R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S100\S100R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S101\S101R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S101\S101R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S102\S102R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S102\S102R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S103\S103R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S103\S103R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S104\S104R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S104\S104R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S105\S105R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S105\S105R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S106\S106R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S106\S106R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S107\S107R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S107\S107R02.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S108\S108R01.edf
# ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S108\S108R02.edf
# No files found in ./EEGData/MNE-eegbci-data/files/eegmmidb/1.0.0\S109

# %%
large_open_data = []    # This is a list of all the data for eyes opened
large_closed_data = []  # This is a list of all the data for eyes closed

for data in opened_files:
    value_open = mne.io.read_raw_edf(data, preload=True, verbose=False).get_data(verbose=False)
    if(len(value_open) == 64):
        large_open_data.append(value_open)

for data in closed_files:
    value_closed = mne.io.read_raw_edf(data, preload=True, verbose=False).get_data(verbose=False)
    if(len(value_closed) == 64):
        large_closed_data.append(value_closed)

print(large_open_data.__len__())   # This is the number of files for eyes opened
print(large_closed_data.__len__()) # This is the number of files for eyes closed
# Out:
# 104
# 104

# %%
open_data = []

for i in range(len(large_open_data)):
    if i not in [1,4,6,13,22,29,31,33,36,43,50,53,60,63,86,87,88,94,95,100,102]: # data that looks sussy
        open_data.append(large_open_data[i])

training_data_open = np.array(open_data)
print(np.shape(training_data_open))
# Out:
# (83, 64, 9760)

# %%
# baseline 

NUM_EPOCHS = 100
PRINT_INTERVAL = 10 # every 10 epoch, print status
BATCH_SIZE = np.shape(training_data_open)[0]
NUM_CHANNELS = 64
SEQUENCE_LENGTH = 9760
LAMBDA_GP = 5

training_data = torch.tensor(training_data_open)

def weights_init(model):
    for m in model.modules():
      if isinstance(m, (nn.Conv1d, nn.ConvTranspose1d)):
        nn.init.normal_(m.weight.data, 0.0, 0.02)

# Gaussian normal distribution
def sample_normal_distribution(i, j, k):
    mu = 0
    sigma = 0.02
    return torch.Tensor(np.random.normal(mu, sigma, (i, j, k)))

def gradient_penalty(D, real, fake):
    alpha = torch.rand((BATCH_SIZE, 1, 1)).repeat(1, NUM_CHANNELS, SEQUENCE_LENGTH)
    interpolated_seq = real * alpha + fake * (1 - alpha)

    # Calculate discriminator scores
    mixed_scores = D(interpolated_seq)

    # Take the gradient of the scores with respect to the images
    gradient = torch.autograd.grad(
        inputs=interpolated_seq,
        outputs=mixed_scores,
        grad_outputs=torch.ones_like(mixed_scores),
        create_graph=True,
        retain_graph=True,
    )[0]
    gradient = gradient.view(gradient.shape[0], -1)
    gradient_norm = gradient.norm(2, dim=1)
    gradient_penalty = torch.mean((gradient_norm - 1) ** 2)
    return gradient_penalty

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.block = nn.Sequential(
            nn.ConvTranspose1d(120, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        x = self.block(x)
        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.block = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.Linear(305, 1)
        )

    def forward(self, x):
        x = x.float()
        x = self.block(x)
        return x

def train():
    critic_err, gen_err, generated_data = [], [], None
    G, D = Generator(), Discriminator()
    weights_init(G)
    weights_init(D)
    critic_optimizer = optim.RMSprop(D.parameters(), lr=2e-4)
    gen_optimizer = optim.RMSprop(G.parameters(), lr=2e-4)

    for epoch in range(NUM_EPOCHS):
        for _ in range(5):
            real = training_data.clone().detach()
            real.requires_grad=True
            noise = sample_normal_distribution(BATCH_SIZE, 120, 305)
            fake = G(noise)
            critic_real = D(real).reshape(-1) # flatten
            critic_fake = D(fake).reshape(-1) # flatten
            gp = gradient_penalty(D, real, fake)
            critic_loss = -(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP * gp
            D.zero_grad()
            critic_loss.backward(retain_graph=True)
            critic_optimizer.step()

        generated_data = fake
        gen_fake = D(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        G.zero_grad()
        loss_gen.backward()
        gen_optimizer.step()

        critic_err.append(critic_loss.item())
        gen_err.append(loss_gen.item())

        if epoch % PRINT_INTERVAL == 0:
            print("Epoch %s: Critic error (%s) Generator err (%s)" % (epoch, critic_err, gen_err))
            values = generated_data[0, 0, :]
            plt.plot(values.tolist())
            plt.show()
            
            # plotting G vs D losses
            plt.figure(figsize=(10,5))
            plt.title("Generator and Discriminator Loss During Training")
            plt.plot(gen_err,label="Generator")
            plt.plot(critic_err,label="Critic")
            plt.xlabel("iterations")
            plt.ylabel("Loss")
            plt.legend()
            plt.show()

    return critic_err, gen_err, generated_data, D, G

critic_err, gen_err, generated_data, disc, gen = train()

torch.save(gen, 'gen.pt')
torch.save(disc, 'disc.pt')
# Out:
# Epoch 0: Critic error ([1.6483993427979802]) Generator err ([-0.025171389803290367])
# Epoch 10: Critic error ([1.6483993427979802, -0.0211659813846152, -0.007684373338464744, -0.06283266695740447, -0.0275683858723364, -0.049407171506422196, -0.05081119399011039, -0.1672020222632899, -0.46503071597606194, -1.0595361902071456, -1.36704197418471]) Generator err ([-0.025171389803290367, 0.0227452851831913, 0.013295899145305157, 0.12416356801986694, 0.09216929972171783, 0.10776695609092712, 0.14920355379581451, 0.2847522795200348, 0.6439281702041626, 1.1178398132324219, 2.6771364212036133])
# Epoch 20: Critic error ([1.6483993427979802, -0.0211659813846152, -0.007684373338464744, -0.06283266695740447, -0.0275683858723364, -0.049407171506422196, -0.05081119399011039, -0.1672020222632899, -0.46503071597606194, -1.0595361902071456, -1.36704197418471, -2.061983173271658, -1.7778154537271849, -3.022665920738235, -2.9897637836091913, -3.4340226573007717, -3.4161370854120356, -4.34170249797341, -3.4567567263688264, -4.46524877658536, -4.431641501403679]) Generator err ([-0.025171389803290367, 0.0227452851831913, 0.013295899145305157, 0.12416356801986694, 0.09216929972171783, 0.10776695609092712, 0.14920355379581451, 0.2847522795200348, 0.6439281702041626, 1.1178398132324219, 2.6771364212036133, 1.7489482164382935, 3.6692864894866943, 2.8888585567474365, 4.976682662963867, 3.4631152153015137, 6.232663154602051, 4.443178176879883, 6.325448989868164, 4.910367488861084, 7.129329204559326])
# Epoch 30: Critic error ([1.6483993427979802, -0.0211659813846152, -0.007684373338464744, -0.06283266695740447, -0.0275683858723364, -0.049407171506422196, -0.05081119399011039, -0.1672020222632899, -0.46503071597606194, -1.0595361902071456, -1.36704197418471, -2.061983173271658, -1.7778154537271849, -3.022665920738235, -2.9897637836091913, -3.4340226573007717, -3.4161370854120356, -4.34170249797341, -3.4567567263688264, -4.46524877658536, -4.431641501403679, -4.825522507090477, -4.869148055297812, -4.5924666487169565, -4.582445784194956, -4.1506774460285705, -4.287724436640249, -4.158759540986461, -4.7992270416994245, -4.23000929462909, -4.212616786720761]) Generator err ([-0.025171389803290367, 0.0227452851831913, 0.013295899145305157, 0.12416356801986694, 0.09216929972171783, 0.10776695609092712, 0.14920355379581451, 0.2847522795200348, 0.6439281702041626, 1.1178398132324219, 2.6771364212036133, 1.7489482164382935, 3.6692864894866943, 2.8888585567474365, 4.976682662963867, 3.4631152153015137, 6.232663154602051, 4.443178176879883, 6.325448989868164, 4.910367488861084, 7.129329204559326, 5.484067440032959, 6.35343599319458, 5.150393486022949, 6.150022029876709, 4.6906232833862305, 5.874690532684326, 4.47844123840332, 6.870986461639404, 4.6600847244262695, 6.0322160720825195])
# Epoch 40: Critic error ([1.6483993427979802, -0.0211659813846152, -0.007684373338464744, -0.06283266695740447, -0.0275683858723364, -0.049407171506422196, -0.05081119399011039, -0.1672020222632899, -0.46503071597606194, -1.0595361902071456, -1.36704197418471, -2.061983173271658, -1.7778154537271849, -3.022665920738235, -2.9897637836091913, -3.4340226573007717, -3.4161370854120356, -4.34170249797341, -3.4567567263688264, -4.46524877658536, -4.431641501403679, -4.825522507090477, -4.869148055297812, -4.5924666487169565, -4.582445784194956, -4.1506774460285705, -4.287724436640249, -4.158759540986461, -4.7992270416994245, -4.23000929462909, -4.212616786720761, -4.228330131232561, -4.083227889388162, -4.044838573098276, -3.9336299658732634, -3.922832049616106, -3.769105267858005, -3.7208277933597937, -3.6275902440105745, -3.7746124636012244, -3.607252607343807]) Generator err ([-0.025171389803290367, 0.0227452851831913, 0.013295899145305157, 0.12416356801986694, 0.09216929972171783, 0.10776695609092712, 0.14920355379581451, 0.2847522795200348, 0.6439281702041626, 1.1178398132324219, 2.6771364212036133, 1.7489482164382935, 3.6692864894866943, 2.8888585567474365, 4.976682662963867, 3.4631152153015137, 6.232663154602051, 4.443178176879883, 6.325448989868164, 4.910367488861084, 7.129329204559326, 5.484067440032959, 6.35343599319458, 5.150393486022949, 6.150022029876709, 4.6906232833862305, 5.874690532684326, 4.47844123840332, 6.870986461639404, 4.6600847244262695, 6.0322160720825
MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R01.edf'
raw = mne.io.read_raw_edf(edf_file, preload=True, verbose=False)


def compute_psd(data, fs, nperseg=256, noverlap=None):
    """
    Compute Power Spectral Density (PSD) using the Welch method.

    Parameters:
        data (array): EEG data array with shape (n_channels, n_samples).
        fs (float): Sampling frequency.
        nperseg (int): Length of each segment for PSD estimation.
        noverlap (int): Number of overlapping samples between segments.
    
    Returns:
        freqs (array): Frequency values.
        psd (array): Power Spectral Density values.
    """
    n_channels, n_samples = data.shape
    psd = np.zeros((n_channels, nperseg // 2 + 1))

    for ch_idx in range(n_channels):
        f, Pxx = plt.psd(data[ch_idx], Fs=fs, NFFT=nperseg, noverlap=noverlap)
        # Add a small epsilon to avoid zero values
        psd[ch_idx] = Pxx + 1e-10

    return f, psd


# Get the EEG data using .get_data()
eeg_data = raw.get_data()
#eeg_data = large_closed_data[0]

# Set the sampling frequency
fs = raw.info['sfreq']

def average_across_arrays(generated_data):
    return generated_data.mean(dim=0)

averaged_data = average_across_arrays(generated_data.detach())
print(np.shape(averaged_data))

# Compute PSD using the custom function
freqs, psd = compute_psd(averaged_data, fs)

# Plot the PSD
plt.figure(figsize=(10, 6))  # Add this line to create a single figure
for ch_idx in range(eeg_data.shape[0]):
    plt.semilogy(freqs, psd[ch_idx], label=f'Channel {ch_idx + 1}')

plt.xlabel('Frequency (Hz)')
plt.ylabel('Power/Frequency (dB/Hz)')
plt.show()
# Out:
# torch.Size([64, 9760])

# %%
# Out:
# Epoch 0: Critic error ([1.6585158978783363]) Generator err ([-0.01610170491039753])
# Epoch 100: Critic error ([1.6585158978783363, 1.2027656337315347, 0.49838881734035284, 0.07449796022892807, 0.01604980674456548, -0.013568552724853938, -0.007479302097999352, 0.0770806468325355, 0.08080878539226496, 0.1476450796054006, 0.25043738080414746, 0.28675544876536446, 0.19056004970470294, 0.1169408053473669, 0.20012667356269534, 0.14599211582904717, 0.2117500529469575, 0.1446560613131528, 0.1793327018555933, 0.17927121649077948, 0.11362757088467795, 0.13209132165155102, 0.06158977801489518, 0.10778848878637445, 0.05907310697594699, 0.0700958659334697, 0.028129801563538295, 0.0702506116836227, -0.02766502326066652, -0.026598168595884916, -0.026856224055718553, -0.08258449683349382, -0.1519870314938111, -0.21164098290227246, -0.32830534900710706, -0.5562791853828978, -1.0099662976242918, -1.392476364952804, -1.721819318368549, -2.2370442242595963, -2.371335369803005, -2.821255555361387, -3.125968057411919, -3.499912429673061, -3.910278270246679, -3.7056579165290975, -4.0111701732639435, -4.560752237528314, -4.519680213343021, -4.439090732905283, -4.186916643199929, -4.286457208401492, -4.526388986045718, -4.4402896878707345, -4.16605727348214, -4.757434436836456, -4.11499801691263, -3.5265652914713352, -3.430858071513585, -3.5820554144021264, -3.746096087076162, -3.7657818171967476, -3.8380697495410905, -3.720013918077199, -4.160854016015432, -4.1797394229561835, -3.9984270726640774, -3.9805920135934234, -3.621317300990345, -3.6055027439043084, -3.398088453591378, -3.346215715741563, -3.2234301215478767, -3.152331936798039, -2.7383853318612847, -3.180635663011446, -3.806731727305688, -3.4720635247975333, -3.2395253853762567, -3.1648396492784565, -3.039233606612327, -2.7595678407688777, -3.533438774269837, -3.1212641478809386, -3.1627281838498407, -2.8647898425427525, -3.096742160661844, -2.8489421054906217, -2.9397889144121723
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
# baseline with deeper gen (+3) and disc (+3)

NUM_EPOCHS = 100
PRINT_INTERVAL = 10 # every 10 epoch, print status
BATCH_SIZE = np.shape(training_data_open)[0]
NUM_CHANNELS = 64
SEQUENCE_LENGTH = 9760
LAMBDA_GP = 5

training_data = torch.tensor(training_data_open)



def weights_init(model):
    for m in model.modules():
      if isinstance(m, (nn.Conv1d, nn.ConvTranspose1d)):
        nn.init.normal_(m.weight.data, 0.0, 0.02)

# Gaussian normal distribution
def sample_normal_distribution(i, j, k):
    mu = 0
    sigma = 0.02
    return torch.Tensor(np.random.normal(mu, sigma, (i, j, k)))

def gradient_penalty(D, real, fake):
    alpha = torch.rand((BATCH_SIZE, 1, 1)).repeat(1, NUM_CHANNELS, SEQUENCE_LENGTH)
    interpolated_seq = real * alpha + fake * (1 - alpha)

    # Calculate discriminator scores
    mixed_scores = D(interpolated_seq)

    # Take the gradient of the scores with respect to the images
    gradient = torch.autograd.grad(
        inputs=interpolated_seq,
        outputs=mixed_scores,
        grad_outputs=torch.ones_like(mixed_scores),
        create_graph=True,
        retain_graph=True,
    )[0]
    gradient = gradient.view(gradient.shape[0], -1)
    gradient_norm = gradient.norm(2, dim=1)
    gradient_penalty = torch.mean((gradient_norm - 1) ** 2)
    return gradient_penalty

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.block = nn.Sequential(
            nn.ConvTranspose1d(120, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        x = self.block(x)
        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.block = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.Linear(305, 1)
        )

    def forward(self, x):
        x = x.float()
        x = self.block(x)
        return x

def train():
    critic_err, gen_err, generated_data = [], [], None
    G, D = Generator(), Discriminator()
    weights_init(G)
    weights_init(D)
    critic_optimizer = optim.RMSprop(D.parameters(), lr=2e-4)
    gen_optimizer = optim.RMSprop(G.parameters(), lr=2e-4)

    for epoch in range(NUM_EPOCHS):
        for _ in range(5):
            real = training_data.clone().detach()
            real.requires_grad=True
            noise = sample_normal_distribution(BATCH_SIZE, 120, 305)
            fake = G(noise)
            critic_real = D(real).reshape(-1) # flatten
            critic_fake = D(fake).reshape(-1) # flatten
            gp = gradient_penalty(D, real, fake)
            critic_loss = -(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP * gp
            D.zero_grad()
            critic_loss.backward(retain_graph=True)
            critic_optimizer.step()

        generated_data = fake
        gen_fake = D(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        G.zero_grad()
        loss_gen.backward()
        gen_optimizer.step()

        critic_err.append(critic_loss.item())
        gen_err.append(loss_gen.item())

        if epoch % PRINT_INTERVAL == 0:
            print("Epoch %s: Critic error (%s) Generator err (%s)" % (epoch, critic_err, gen_err))
            values = generated_data[0, 0, :]
            plt.plot(values.tolist())
            plt.show()
            
            # plotting G vs D losses
            plt.figure(figsize=(10,5))
            plt.title("Generator and Discriminator Loss During Training")
            plt.plot(gen_err,label="Generator")
            plt.plot(critic_err,label="Critic")
            plt.xlabel("iterations")
            plt.ylabel("Loss")
            plt.legend()
            plt.show()

    return critic_err, gen_err, generated_data, D, G

critic_err, gen_err, generated_data2, disc, gen = train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 172
#     168             plt.show()
#     170     return critic_err, gen_err, generated_data, D, G
# --> 172 critic_err, gen_err, generated_data2, disc, gen = train()
#
# Cell In[50], line 137, in train()
#     135 fake = G(noise)
#     136 critic_real = D(real).reshape(-1) # flatten
# --> 137 critic_fake = D(fake).reshape(-1) # flatten
#     138 gp = gradient_penalty(D, real, fake)
#     139 critic_loss = -(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP * gp
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[50], line 119, in Discriminator.forward(self, x)
#     117 def forward(self, x):
#     118     x = x.float()
# --> 119     x = self.block(x)
#     120     return x
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\conv.py:313, in Conv1d.forward(self, input)
#     312 def forward(self, input: Tensor) -> Tensor:
# --> 313     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\conv.py:309, in Conv1d._conv_forward(self, input, weight, bias)
#     305 if self.padding_mode != 'zeros':
#     306     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     307                     weight, bias, self.stride,
#     308                     _single(0), self.dilation, self.groups)
# --> 309 return F.conv1d(input, weight, bias, self.stride,
#     310                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
# baseline with clipping values

NUM_EPOCHS = 100
PRINT_INTERVAL = 10 # every 10 epoch, print status
BATCH_SIZE = np.shape(training_data_open)[0]
NUM_CHANNELS = 64
SEQUENCE_LENGTH = 9760
LAMBDA_GP = 5

training_data = torch.tensor(training_data_open)


def weights_init(model):
    for m in model.modules():
      if isinstance(m, (nn.Conv1d, nn.ConvTranspose1d)):
        nn.init.normal_(m.weight.data, 0.0, 0.02)

# Gaussian normal distribution
def sample_normal_distribution(i, j, k):
    mu = 0
    sigma = 0.02
    return torch.Tensor(np.random.normal(mu, sigma, (i, j, k)))

def gradient_penalty(D, real, fake):
    alpha = torch.rand((BATCH_SIZE, 1, 1)).repeat(1, NUM_CHANNELS, SEQUENCE_LENGTH)
    interpolated_seq = real * alpha + fake * (1 - alpha)

    # Calculate discriminator scores
    mixed_scores = D(interpolated_seq)

    # Take the gradient of the scores with respect to the images
    gradient = torch.autograd.grad(
        inputs=interpolated_seq,
        outputs=mixed_scores,
        grad_outputs=torch.ones_like(mixed_scores),
        create_graph=True,
        retain_graph=True,
    )[0]
    gradient = gradient.view(gradient.shape[0], -1)
    gradient_norm = gradient.norm(2, dim=1)
    gradient_penalty = torch.mean((gradient_norm - 1) ** 2)
    return gradient_penalty

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.block = nn.Sequential(
            nn.ConvTranspose1d(120, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        x = self.block(x)
        x = torch.clamp(x, min=-0.5, max=0.5)
        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.block = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.Linear(305, 1)
        )

    def forward(self, x):
        x = x.float()
        x = self.block(x)
        return x

def train():
    critic_err, gen_err, generated_data = [], [], None
    G, D = Generator(), Discriminator()
    weights_init(G)
    weights_init(D)
    critic_optimizer = optim.RMSprop(D.parameters(), lr=2e-4)
    gen_optimizer = optim.RMSprop(G.parameters(), lr=2e-4)

    for epoch in range(NUM_EPOCHS):
        for _ in range(5):
            real = training_data.clone().detach()
            real.requires_grad=True
            noise = sample_normal_distribution(BATCH_SIZE, 120, 305)
            fake = G(noise)
            critic_real = D(real).reshape(-1) # flatten
            critic_fake = D(fake).reshape(-1) # flatten
            gp = gradient_penalty(D, real, fake)
            critic_loss = -(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP * gp
            D.zero_grad()
            critic_loss.backward(retain_graph=True)
            critic_optimizer.step()

        generated_data = fake
        gen_fake = D(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        G.zero_grad()
        loss_gen.backward()
        gen_optimizer.step()

        critic_err.append(critic_loss.item())
        gen_err.append(loss_gen.item())

        if epoch % PRINT_INTERVAL == 0:
            print("Epoch %s: Critic error (%s) Generator err (%s)" % (epoch, critic_err, gen_err))
            values = generated_data[0, 0, :]
            plt.plot(values.tolist())
            plt.show()
            
            # plotting G vs D losses
            plt.figure(figsize=(10,5))
            plt.title("Generator and Discriminator Loss During Training")
            plt.plot(gen_err,label="Generator")
            plt.plot(critic_err,label="Critic")
            plt.xlabel("iterations")
            plt.ylabel("Loss")
            plt.legend()
            plt.show()

    return critic_err, gen_err, generated_data, D, G

critic_err, gen_err, generated_data3, disc, gen = train()

# %%
# baseline with 500 epoch

NUM_EPOCHS = 500
PRINT_INTERVAL = 100 # every 10 epoch, print status
BATCH_SIZE = np.shape(training_data_open)[0]
NUM_CHANNELS = 64
SEQUENCE_LENGTH = 9760
LAMBDA_GP = 5

training_data = torch.tensor(training_data_open)


def weights_init(model):
    for m in model.modules():
      if isinstance(m, (nn.Conv1d, nn.ConvTranspose1d)):
        nn.init.normal_(m.weight.data, 0.0, 0.02)

# Gaussian normal distribution
def sample_normal_distribution(i, j, k):
    mu = 0
    sigma = 0.02
    return torch.Tensor(np.random.normal(mu, sigma, (i, j, k)))

def gradient_penalty(D, real, fake):
    alpha = torch.rand((BATCH_SIZE, 1, 1)).repeat(1, NUM_CHANNELS, SEQUENCE_LENGTH)
    interpolated_seq = real * alpha + fake * (1 - alpha)

    # Calculate discriminator scores
    mixed_scores = D(interpolated_seq)

    # Take the gradient of the scores with respect to the images
    gradient = torch.autograd.grad(
        inputs=interpolated_seq,
        outputs=mixed_scores,
        grad_outputs=torch.ones_like(mixed_scores),
        create_graph=True,
        retain_graph=True,
    )[0]
    gradient = gradient.view(gradient.shape[0], -1)
    gradient_norm = gradient.norm(2, dim=1)
    gradient_penalty = torch.mean((gradient_norm - 1) ** 2)
    return gradient_penalty

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.block = nn.Sequential(
            nn.ConvTranspose1d(120, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
            nn.Upsample(scale_factor=2),
            nn.ConvTranspose1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.BatchNorm1d(64, affine=True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        x = self.block(x)
        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.block = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.AvgPool1d(kernel_size=2, stride=2),
            nn.Conv1d(64, 64, kernel_size=9, stride=1, padding=4),
            nn.LeakyReLU(0.2),
            nn.Linear(305, 1)
        )

    def forward(self, x):
        x = x.float()
        x = self.block(x)
        return x

def train():
    critic_err, gen_err, generated_data = [], [], None
    G, D = Generator(), Discriminator()
    weights_init(G)
    weights_init(D)
    critic_optimizer = optim.RMSprop(D.parameters(), lr=2e-4)
    gen_optimizer = optim.RMSprop(G.parameters(), lr=2e-4)

    for epoch in range(NUM_EPOCHS):
        for _ in range(5):
            real = training_data.clone().detach()
            real.requires_grad=True
            noise = sample_normal_distribution(BATCH_SIZE, 120, 305)
            fake = G(noise)
            critic_real = D(real).reshape(-1) # flatten
            critic_fake = D(fake).reshape(-1) # flatten
            gp = gradient_penalty(D, real, fake)
            critic_loss = -(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP * gp
            D.zero_grad()
            critic_loss.backward(retain_graph=True)
            critic_optimizer.step()

        generated_data = fake
        gen_fake = D(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        G.zero_grad()
        loss_gen.backward()
        gen_optimizer.step()

        critic_err.append(critic_loss.item())
        gen_err.append(loss_gen.item())

        if epoch % PRINT_INTERVAL == 0:
            print("Epoch %s: Critic error (%s) Generator err (%s)" % (epoch, critic_err, gen_err))
            values = generated_data[0, 0, :]
            plt.plot(values.tolist())
            plt.show()
            
            # plotting G vs D losses
            plt.figure(figsize=(10,5))
            plt.title("Generator and Discriminator Loss During Training")
            plt.plot(gen_err,label="Generator")
            plt.plot(critic_err,label="Critic")
            plt.xlabel("iterations")
            plt.ylabel("Loss")
            plt.legend()
            plt.show()

    return critic_err, gen_err, generated_data, D, G

critic_err, gen_err, generated_data1, disc, gen = train()
